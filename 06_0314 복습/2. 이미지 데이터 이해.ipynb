# %% [markdown]
# ### 머신러닝을 위한 이미지 데이터
# - 기계 학습을 위한 데이터 준비

# %%
import os
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 이미지 그레이 스케일로 읽어오기
img = cv2.imread("/content/swiss-army-ant.jpg")
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray_img, cmap="gray")
plt.show()

# %%
# 전체 이미지 데이터
dirs = ["ants", "bees"]

# 이미지에 대한 설명변수(픽셀 값)와 목적변수(레이블)의 값을 저장할 리스트 생성
pixels = []
labels = []

# 이미지를 읽어와 필요한 모양으로 데이터 처리 후 리스트에 저장
# enumerate(dirs): 연속형 데이터의 index와 value 원소를 동시에 접근
for i, d in enumerate(dirs):
    # 파일명 취득
    files = os.listdir("/content/drive/MyDrive/multi/0406/data" + d)

print(files)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-20-2eb738d2b079> in <module>()
#      10 for i, d in enumerate(dirs):
#      11     # 파일명 취득
# ---> 12     files = os.listdir("/content/drive/MyDrive/multi/0406/data" + d)
#      13
#      14 print(files)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/multi/0406/dataants'
