# %% [markdown]
# html 태그 참조
# - https://ofcourse.kr/html-course/HTML-%EC%9E%85%EB%AC%B8

# %% [markdown]
# google map API 체험
#
# - 구글맵 API 가입
# - 참고: https://cloud.google.com/maps-platform/
# - 참고: https://tinyurl.com/y3uw2ppf

# %%
#!pip install googlemaps
import googlemaps    # 데이터는 Json 형식(딕셔너리)으로 제공

user_Key='AIzaSyB8Ua6RAi-ZC5WoE4xbEtlnEWZ_XOpaWGk'
gmaps=googlemaps.Client(key=user_Key)

sch = input("조회할 명칭 / 조수를 입력하세요:")
ggmap = gmaps.geocode(sch, language='ko')
ggmap
# Out:
# 조회할 상호 / 명칭을 입력하세요:서울시데이터센터
# [{'address_components': [{'long_name': '３９３−１',
#     'short_name': '３９３−１',
#     'types': ['premise']},
#    {'long_name': '서초동',
#     'short_name': '서초동',
#     'types': ['political', 'sublocality', 'sublocality_level_2']},
#    {'long_name': '서초구',
#     'short_name': '서초구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '137-070',
#     'short_name': '137-070',
#     'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 서초구 서초동 393-1',
#   'geometry': {'location': {'lat': 37.4795371, 'lng': 127.0218775},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.4808860802915,
#      'lng': 127.0232264802915},
#     'southwest': {'lat': 37.47818811970851, 'lng': 127.0205285197085}}},
#   'partial_match': True,
#   'place_id': 'ChIJJTbDqj2hfDUR5Yr6l5d5-f0',
#   'plus_code': {'compound_code': 'F2HC+RQ 대한민국 서울특별시',
#    'global_code': '8Q99F2HC+RQ'},
#   'types': ['establishment', 'point_of_interest']}]

# %%
print(f"주소:", ggmap[0]['formatted_address'])
print(ggmap[0]['geometry'])
print()
print(ggmap[0]['geometry']['location'])
print()
print(ggmap[0]['geometry']['location']['lat'])
print(ggmap[0]['geometry']['location']['lng'])
# Out:
# 주소: 대한민국 서울특별시 서초구 서초동 393-1
# {'location': {'lat': 37.4795371, 'lng': 127.0218775}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 37.4808860802915, 'lng': 127.0232264802915}, 'southwest': {'lat': 37.47818811970851, 'lng': 127.0205285197085}}}
#
# {'lat': 37.4795371, 'lng': 127.0218775}
#
# 37.4795371
# 127.0218775

# %% [markdown]
# 유가정보를 이용한 지도 그리기

# %%
#!pip install folium
#!pip install pandas
#!pip install xlrd
# Out:
# Collecting xlrd
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
# Installing collected packages: xlrd
# Successfully installed xlrd-2.0.1

# %%
import pandas as pd
import folium
import googlemaps
from glob import glob

#glob("c:/pydata/*.xls")  지정한 폴더에서 원하는 파일만 추출해 리스트로 제공
filenames = glob("c:/pydata/*주유소*.xls")

df = pd.DataFrame()

for fname in filenames:
    tmp = pd.read_excel(fname, header=2)
    df = pd.concat([df, tmp])

df = df.reset_index(drop=True)

# %%
df.head()
df.tail()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76 entries, 0 to 75
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   지역      76 non-null     object
#  1   상호      76 non-null     object
#  2   주소      76 non-null     object
#  3   상표      76 non-null     object
#  4   전화번호    76 non-null     object
#  5   셀프여부    76 non-null     object
#  6   고급휘발유   76 non-null     object
#  7   휘발유     76 non-null     object
#  8   경유      76 non-null     object
#  9   실내등유    76 non-null     object
# dtypes: object(10)
# memory usage: 6.1+ KB

# %%
# 지도에 표시, 필요한 자료 = [상호, 주소, 상표, 휘발유]만 추출하기

mapdf = df[["상호", "주소", "상표", "휘발유"]]
mapdf.head()
# Out:
#                      상호                            주소      상표   휘발유
# 0  재건에너지 재정제2주유소 고속셀프지점  서울특별시 강동구  천호대로 1246 (둔촌제2동)  현대오일뱅크  2032
# 1                구천면주유소         서울 강동구 구천면로 357 (암사동)  현대오일뱅크  2033
# 2         지에스칼텍스㈜ 신월주유소        서울 강동구 양재대로 1323 (성내동)   GS칼텍스  2035
# 3       (주)퍼스트오일 코알라주유소     서울특별시 강동구  올림픽로 556 (성내동)   S-OIL  2058
# 4     현대오일뱅크㈜직영 명일셀프주유소          서울 강동구 고덕로 168 (명일동)  현대오일뱅크  2063

# %%
# 권장

for i in mapdf.index:
    mapdf.loc["주소"] = mapdf.loc[i, "주소"].split("(")[0]
    
mapdf.head()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_10080\1513854312.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mapdf.loc["주소"] = mapdf.loc[i, "주소"].split("(")[0]
#                      상호                     주소      상표   휘발유
# 0  재건에너지 재정제2주유소 고속셀프지점  서울특별시 강동구  천호대로 1246   현대오일뱅크  2032
# 1                구천면주유소       서울 강동구 구천면로 357   현대오일뱅크  2033
# 2         지에스칼텍스㈜ 신월주유소      서울 강동구 양재대로 1323    GS칼텍스  2035
# 3       (주)퍼스트오일 코알라주유소   서울특별시 강동구  올림픽로 556    S-OIL  2058
# 4     현대오일뱅크㈜직영 명일셀프주유소        서울 강동구 고덕로 168   현대오일뱅크  2063

# %%
# 주소에서 ()에 있는 데이터 제거

mapdf.iloc[0,1].split("(")[0]

for i in range(len(mapdf)):
    mapdf.iloc[i, 1] = mapdf.iloc[i, 1].split("(")[0]
    
mapdf.head()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_10080\1673038701.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mapdf.iloc[i, 1] = mapdf.iloc[i, 1].split("(")[0]
#                      상호                     주소      상표   휘발유
# 0  재건에너지 재정제2주유소 고속셀프지점  서울특별시 강동구  천호대로 1246   현대오일뱅크  2032
# 1                구천면주유소       서울 강동구 구천면로 357   현대오일뱅크  2033
# 2         지에스칼텍스㈜ 신월주유소      서울 강동구 양재대로 1323    GS칼텍스  2035
# 3       (주)퍼스트오일 코알라주유소   서울특별시 강동구  올림픽로 556    S-OIL  2058
# 4     현대오일뱅크㈜직영 명일셀프주유소        서울 강동구 고덕로 168   현대오일뱅크  2063

# %%
# google API를 이용한 주소 검색(위도 / 경도 추출)

user_Key='AIzaSyB8Ua6RAi-ZC5WoE4xbEtlnEWZ_XOpaWGk'
gmaps=googlemaps.Client(key=user_Key)

ggmap = gmaps.geocode("서울 양천구 신정로 236", language='ko')
lat = ggmap[-1]['geometry']['location']['lat']
lng = ggmap[-1]['geometry']['location']['lng']

print(lat,lng)
# Out:
# 37.5105184 126.8476876

# %%
# mapdf의 주소를 이용해 위도 / 경도 필드 추가

lat=[];lng=[]

for i in mapdf.index:
    ggmap = gmaps.geocode(mapdf.loc[i, "주소"], language='ko')
    lat.append(ggmap[-1]['geometry']['location']['lat'])
    lng.append(ggmap[-1]['geometry']['location']['lng'])
    
mapdf['위도'] = lat
mapdf['경도'] = lng
mapdf.head()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_10080\245131101.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mapdf['위도'] = lat
# C:\Users\User\AppData\Local\Temp\ipykernel_10080\245131101.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mapdf['경도'] = lng
#                      상호                     주소      상표   휘발유         위도  \
# 0  재건에너지 재정제2주유소 고속셀프지점  서울특별시 강동구  천호대로 1246   현대오일뱅크  2032  37.536464
# 1                구천면주유소       서울 강동구 구천면로 357   현대오일뱅크  2033  37.550421
# 2         지에스칼텍스㈜ 신월주유소      서울 강동구 양재대로 1323    GS칼텍스  2035  37.524511
# 3       (주)퍼스트오일 코알라주유소   서울특별시 강동구  올림픽로 556    S-OIL  2058  37.531288
# 4     현대오일뱅크㈜직영 명일셀프주유소        서울 강동구 고덕로 168   현대오일뱅크  2063  37.554452
#
#            경도
# 0  127.149316
# 1  127.138233
# 2  127.134416
# 3  127.121210
# 4  127.143956

# %%
# 주유소 1개 출력

m = folium.Map(location=[37.5373614, 127.1244733], zoom_start=13)

folium.Marker([mapdf.loc[75, "위도"], mapdf.loc[0, "경도"]],
              popup=mapdf.loc[75, "상호"],
              icon=folium.Icon(color='red')).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_00b2c5822f5b4575adadbb68fa00e09e%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_00b2c5822f5b4575adadbb68fa00e09e%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_00b2c5822f5b4575adadbb68fa00e09e%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_00b2c5822f5b4575adadbb68fa00e09e%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.5373614%2C%20127.1244733%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
mapdf.tail()
# Out:
#                  상호                    주소               상표              휘발유  \
# 72          제이제이주유소        서울 강남구 언주로 716           현대오일뱅크             2545
# 73            경원주유소      서울 강남구 도산대로 428             S-OIL                -
# 74            동우주유소  서울특별시 강남구  봉은사로 311             SK에너지                -
# 75            삼성주유소       서울 강남구 삼성로 521             SK에너지                -
# 주소  서울 강남구 삼성로 521        서울 강남구 삼성로 521   서울 강남구 삼성로 521   서울 강남구 삼성로 521
#
#            위도          경도
# 72  37.517636  127.035756
# 73  37.523255  127.042720
# 74  37.509823  127.040843
# 75  37.508507  127.055165
# 주소  37.508507  127.055165

# %%
# 전체 주유소 출력

m = folium.Map(location=[37.5373614, 127.1244733], zoom_start=13)
for i in mapdf.index:
    folium.Marker([mapdf.loc[i, "위도"], mapdf.loc[i, "경도"]],
              popup=mapdf.loc[i, "상호"],
              icon=folium.Icon(color='red')).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_dc25b6129ba74d798cb460edea601045%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_dc25b6129ba74d798cb460edea601045%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_dc25b6129ba74d798cb460edea601045%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_dc25b6129ba74d798cb460edea601045%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.5373614%2C%20127.1244733%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...
